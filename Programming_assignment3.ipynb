# %%
things = ["mozzarella","cinderella","salmonella"]
things[1] = "CINDERELLA"
print(things)

#when I change the element is automatically change in the list as well
# Out:
# ['mozzarella', 'CINDERELLA', 'salmonella']

# %%
things[0] = "MOZZARELLA"
print(things)
# Out:
# ['MOZZARELLA', 'CINDERELLA', 'salmonella']

# %%
things.remove("salmonella")
print(things)
# Out:
# ['MOZZARELLA', 'CINDERELLA']

# %%
def good():
    name = ["Harry", "Ron", "Hermione"]
    return name
    
good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %%
def get_odds():
    num_odds = []
    num = 0
    for num in range(10):
        num = num +1
        if num %2 != 0:
            num_odds.append(num)
    print(num_odds[2])

get_odds()
# Out:
# 5
